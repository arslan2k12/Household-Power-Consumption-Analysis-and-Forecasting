# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from numpy.random import rand
import numpy as np

# %%
fig=plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,1,1)

people = ('dToU rates more predictable', 'no dToU during evening peak-time', 'dToU only on daytimes of weekdays','dToU only on weekends',   'dToU rates longer and simpler')
y_pos = np.arange(len(people))
performance = [222,191,89,54,0]


my_cmap = cm.get_cmap('jet')
# get normalize function (takes data in range [vmin, vmax] -> [0, 1])
my_norm = Normalize(vmin=0, vmax=5)
# some boring fake data
my_data = 5*rand(5)


ax.barh(y_pos, performance,  align='center',
        color=my_cmap(my_norm(my_data)))
ax.set_yticks(y_pos)
ax.set_yticklabels(people, fontsize=20)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Votes', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
ax.set_title('How to make dToU program more interesting?', fontsize=30)
plt.savefig('qs12_ars.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(15,10))
# plt.rcParams.update({'font.size': 30})
plt.plot(c,'mo-',label='Adults+Old (Age 18-100)', linewidth=3)
plt.plot(b,'co-',label='Adult + Kids (Age 0-64)', linewidth=3)
plt.plot(a,'bo-', label='Adults (Age 18-64)', linewidth=3)


plt.ylabel('Electricity (Watt-hour)', fontsize=20)
plt.xlabel('Time (months)', fontsize=20)

x=np.arange(0,12)
y=np.arange(1,12+1,)
plt.xticks(x, y);

plt.tick_params(axis='both', which='major', labelsize=20)

# plt.ylim(ymin=x_min,ymax=x_max)
plt.title('Energy consumption vs Insulation Type', fontsize=30)
plt.legend(loc='upper center', fontsize=25,framealpha=0.5)
plt.savefig('ages_ars.pdf', bbox_inches='tight')
