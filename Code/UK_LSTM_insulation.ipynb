# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=[183.3287929,162.3281286,180.6573857,162.89965,167.6408071,157.6285429,171.8691786,164.8752714,161.8278071,170.2401929,172.0948571,179.5542429]

# %%
b=[227.6228286,201.0539714,226.1621143,206.7887143,209.9910286,201.9564,212.1476,205.2561429,204.2026571,215.8828571,213.6422571,229.2156286]

# %%
c=[321.9402727,285.5062273,315.6895,277.1679545,283.8450455,263.2356818,269.0887727,258.1019545,267.8764545,293.7121818,302.2806818,317.9309091]

# %%
d=[168.8469704,149.4124911,167.5514852,148.2556746,151.6006391,145.3333787,148.9206036,147.5156154,146.9571361,155.7451598,155.5143195,162.5011598]

# %%
e=[120.614,111.9224,118.0618,109.8908,120.55,114.1646,118.6358,113.5064,120.0468,126.736,122.72,125.7212]

# %%
plt.figure(figsize=(15,10))
# plt.rcParams.update({'font.size': 30})
plt.plot(c,'mo-',label='Wall', linewidth=3)
plt.plot(b,'co-',label='Double Glazing', linewidth=3)
plt.plot(a,'bo-', label='Double Glazing+Roof', linewidth=3)
plt.plot(d,'go-',label='Double Glazing+Roof+Floor', linewidth=3)
plt.plot(e,'ro-',label='All Types of Insulation', linewidth=3)


plt.ylabel('Electricity (Watt-hour)', fontsize=20)
plt.xlabel('Time (months)', fontsize=20)

x=np.arange(0,12)
y=np.arange(1,12+1,)
plt.xticks(x, y);

plt.tick_params(axis='both', which='major', labelsize=20)

# plt.ylim(ymin=x_min,ymax=x_max)
plt.title('Energy consumption vs Insulation Type', fontsize=30)
plt.legend(loc='upper center', fontsize=18,framealpha=0.5)
plt.savefig('insulations_ars.pdf', bbox_inches='tight')
