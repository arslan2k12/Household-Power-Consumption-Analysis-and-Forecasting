# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=[234.273601,207.419285,232.7987617,208.5633523,212.3843264,200.4256218,210.2692746,205.7215959,202.9748135,217.4005959,219.1415699,232.3132694]

# %%
b=[220.16875,195.71965,217.95365,189.08585,194.243225,185.118525,192.26135,190.714775,189.05485,205.343825,207.936875,223.2777]

# %%
c=[241.5107349,215.4430723,240.659759,219.2145181,224.1576265,209.3496145,221.3604458,213.4559518,210.863759,223.2543735,225.2519518,236.9879277]

# %%
plt.figure(figsize=(15,10))
# plt.rcParams.update({'font.size': 30})
plt.plot(c,'mo-',label='Adults+Old (Age 18-100)', linewidth=3)
plt.plot(a,'bo-', label='Adults (Age 18-64)', linewidth=3)
plt.plot(b,'co-',label='Adult + Kids (Age 0-64)', linewidth=3)



plt.ylabel('Electricity (Watt-hour)', fontsize=20)
plt.xlabel('Time (months)', fontsize=20)

x=np.arange(0,12)
y=np.arange(1,12+1,)
plt.xticks(x, y);

plt.tick_params(axis='both', which='major', labelsize=20)

# plt.ylim(ymin=x_min,ymax=x_max)
plt.title('Energy consumption vs Age catagory', fontsize=30)
plt.legend(loc='upper center', fontsize=25,framealpha=0.5)
plt.savefig('ages_ars.pdf', bbox_inches='tight')
